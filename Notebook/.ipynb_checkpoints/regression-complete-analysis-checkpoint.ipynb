# %% [markdown]
# ## Preparing Data:

# %%
# Importing Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
Training_Dataset = pd.read_csv("/home/cong/Desktop/Linear-regression/Dataset/train.csv")
Training_Dataset = Training_Dataset.dropna()
X_train = np.array(Training_Dataset.iloc[:, :-1].values) # Independent Variable
y_train = np.array(Training_Dataset.iloc[:, 1].values) # Dependent Variable

# %%
Testing_Dataset = pd.read_csv("/home/cong/Desktop/Linear-regression/Dataset/test.csv")
Testing_Dataset = Testing_Dataset.dropna()
X_test = np.array(Testing_Dataset.iloc[:, :-1].values) # Independent Variable
y_test = np.array(Testing_Dataset.iloc[:, 1].values) # Dependent Variable

# %%
# Training the Model
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
accuracy = regressor.score(X_test, y_test)
print('Accuracy = '+ str(accuracy))
# Out:
# Accuracy = 0.9888014444327563

# %%
plt.style.use('seaborn')
plt.scatter(X_test, y_test, color = 'red', marker = 'o', s = 35, alpha = 0.5,
          label = 'Test data')
plt.plot(X_train, regressor.predict(X_train), color = 'blue', label='Model Plot')
plt.title('Predicted Values vs Inputs')
plt.xlabel('Inputs')
plt.ylabel('Predicted Values')
plt.legend(loc = 'upper left')
plt.show()

# %% [markdown]
# ## Preparing Data:

# %%
dataset = pd.read_csv('/home/cong/Desktop/Linear-regression/Dataset/insurance.csv')
print(dataset)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
X = dataset.iloc[:, :-1] # Independent Variable
y = dataset.iloc[:, -1] # Dependent Variable

# %%
# We have to apply encoding in the dataset as there are words present.
# for 'sex' and 'smoker' column we will apply Label Encoding as there are only 2 catagories
# for 'region' we will apply OneHot Encoding as there are more than 2 catagories

# Label Encoding:
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X.iloc[:, 1] = le.fit_transform(X.iloc[:, 1])
X.iloc[:, 4] = le.fit_transform(X.iloc[:, 4])

# OneHot Encoding:
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [5])], remainder='passthrough')
X = np.array(ct.fit_transform(X))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# Training the Model
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
accuracy = regressor.score(X_test, y_test)
print('Accuracy = '+ str(accuracy))
# Out:
# Accuracy = 0.7999876970680434

# %%
dataset = pd.read_csv('/home/cong/Desktop/Linear-regression/Dataset/polynomial-regression.csv')
X = dataset.iloc[:, :-1] # Independent Variable
y = dataset.iloc[:, -1] # Dependent Variable

# %%
# Trianing the Model
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 5)
X_poly = poly_reg.fit_transform(X)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
plt.style.use('seaborn')
plt.scatter(X, y, color = 'red', marker = 'o', s = 35, alpha = 0.5,
          label = 'Test data')
plt.plot(X, lin_reg_2.predict(poly_reg.fit_transform(X)), color = 'blue', label='Model Plot')
plt.title('Predicted Values vs Inputs')
plt.xlabel('Inputs')
plt.ylabel('Predicted Values')
plt.legend(loc = 'upper left')
plt.show()

# %%
Training_Dataset = pd.read_csv("/home/cong/Desktop/Linear-regression/Dataset/train.csv")
Training_Dataset = Training_Dataset.dropna()
X_train = np.array(Training_Dataset.iloc[:, :-1].values) # Independent Variable
y_train = np.array(Training_Dataset.iloc[:, 1].values) # Dependent Variable
y_train = y_train.reshape(len(y_train),1)

# %%
Testing_Dataset = pd.read_csv("/home/cong/Desktop/Linear-regression/Dataset/test.csv")
Testing_Dataset = Testing_Dataset.dropna()
X_test = np.array(Testing_Dataset.iloc[:, :-1].values) # Independent Variable
y_test = np.array(Testing_Dataset.iloc[:, 1].values) # Dependent Variable
y_test = y_test.reshape(len(y_test),1)

# %%
# Scalling X and y
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.fit_transform(X_test)
y_train = sc_y.fit_transform(y_train)
y_test = sc_y.fit_transform(y_test)

# %%
# Training the Model
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X_train, y_train)
# Out:
# /home/cong/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR()

# %%
accuracy = regressor.score(X_test, y_test)
print('Accuracy = '+ str(accuracy))
# Out:
# Accuracy = 0.9885979938016756

# %%
plt.scatter(sc_X.inverse_transform(X_test), sc_y.inverse_transform(y_test), color = 'red', marker = 'o', s = 35, alpha = 0.5, label = 'Test data')
plt.plot(sc_X.inverse_transform(X_test), sc_y.inverse_transform(regressor.predict(X_test)), color = 'blue', label='Model Plot')
plt.title('Predicted Values vs Inputs')
plt.xlabel('Inputs')
plt.ylabel('Predicted Values')
plt.legend(loc = 'upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [21], in <cell line: 2>()
#       1 plt.scatter(sc_X.inverse_transform(X_test), sc_y.inverse_transform(y_test), color = 'red', marker = 'o', s = 35, alpha = 0.5, label = 'Test data')
# ----> 2 plt.plot(sc_X.inverse_transform(X_test), sc_y.inverse_transform(regressor.predict(X_test)), color = 'blue', label='Model Plot')
#       3 plt.title('Predicted Values vs Inputs')
#       4 plt.xlabel('Inputs')
#
# File ~/.local/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:1017, in StandardScaler.inverse_transform(self, X, copy)
#    1014 check_is_fitted(self)
#    1016 copy = copy if copy is not None else self.copy
# -> 1017 X = check_array(
#    1018     X,
#    1019     accept_sparse="csr",
#    1020     copy=copy,
#    1021     dtype=FLOAT_DTYPES,
#    1022     force_all_finite="allow-nan",
#    1023 )
#    1025 if sparse.issparse(X):
#    1026     if self.with_mean:
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:879, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     877     # If input is 1D raise error
#     878     if array.ndim == 1:
# --> 879         raise ValueError(
#     880             "Expected 2D array, got 1D array instead:\narray={}.\n"
#     881             "Reshape your data either using array.reshape(-1, 1) if "
#     882             "your data has a single feature or array.reshape(1, -1) "
#     883             "if it contains a single sample.".format(array)
#     884         )
#     886 if dtype_numeric and array.dtype.kind in "USV":
#     887     raise ValueError(
#     888         "dtype='numeric' is not compatible with arrays of bytes/strings."
#     889         "Convert your data to numeric values explicitly instead."
#     890     )
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 0.91602749 -1.05010232 -1.01352329 -1.08690763 -0.52055108 -1.27241139
#   0.38973714  1.52944859 -1.08690763 -1.59574172 -1.61848208 -1.1239029
#   1.55645896  0.38973714 -0.52055108 -1.27241139  0.49516782 -1.30915085
#   1.27015711  0.6355415   1.33959437  0.00386287  1.33959437 -0.8342959
#   1.58157873  0.24921614  0.98655782 -1.05010232  1.47064009 -0.8342959
#   1.62524977 -0.69428074 -0.62476687  1.02193846 -0.79909306 -0.13622082
#   0.07390816  0.6355415  -0.79909306 -0.62476687  1.40684866  0.70561349
#  -0.03115571  0.88086633 -1.61848208 -0.48576536  0.67058487  0.60047884
#  -0.3811811  -0.55530583  1.50077001  1.30507919  0.0388831  -0.69428074
#   0.28432693 -1.68008979 -0.41608106  0.46003116  0.6355415   0.21412242
#  -1.34545447  0.74063458  0.88086633  0.35459117  1.09291056 -1.16103416
#  -0.3462462  -0.03115571  0.14398658 -1.34545447 -0.17124594 -1.34545447
#   0.98655782  0.07390816 -1.27241139 -0.79909306  1.0573935   0.6355415
#   0.0388831   1.16402649  0.60047884 -0.8342959   0.1790462  -0.10119677
#  -0.3811811  -0.41608106  1.09291056  1.64335979  0.28432693 -0.27629278
#   0.565395   -0.45094277  0.4248857   1.40684866  0.31945299 -1.30915085
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
Training_Dataset = pd.read_csv("/home/cong/Desktop/Linear-regression/Dataset/train.csv")
Training_Dataset = Training_Dataset.dropna()
X_train = np.array(Training_Dataset.iloc[:, :-1].values) # Independent Variable
y_train = np.array(Training_Dataset.iloc[:, 1].values) # Dependent Variable

# %%
Testing_Dataset = pd.read_csv("/home/cong/Desktop/Linear-regression/Dataset/test.csv")
Testing_Dataset = Testing_Dataset.dropna()
X_test = np.array(Testing_Dataset.iloc[:, :-1].values) # Independent Variable
y_test = np.array(Testing_Dataset.iloc[:, 1].values) # Dependent Variable

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state = 0)
regressor.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
accuracy = regressor.score(X_test, y_test)
print('Accuracy = '+ str(accuracy))
# Out:
# Accuracy = 0.9871681731403525

# %%
X_grid = np.arange(min(X_test), max(X_test), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X_test, y_test, color = 'red', marker = 'o', s = 35, alpha = 0.5,
          label = 'Test data')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue', label='Model Plot')
plt.title('Predicted Values vs Inputs')
plt.xlabel('Inputs')
plt.ylabel('Predicted Values')
plt.legend(loc = 'upper left')
plt.show()

# %%
Training_Dataset = pd.read_csv("/home/cong/Desktop/Linear-regression/Dataset/train.csv")
Training_Dataset = Training_Dataset.dropna()
X_train = np.array(Training_Dataset.iloc[:, :-1].values) # Independent Variable
y_train = np.array(Training_Dataset.iloc[:, 1].values) # Dependent Variable

# %%
Testing_Dataset = pd.read_csv("/home/cong/Desktop/Linear-regression/Dataset/test.csv")
Testing_Dataset = Testing_Dataset.dropna()
X_test = np.array(Testing_Dataset.iloc[:, :-1].values) # Independent Variable
y_test = np.array(Testing_Dataset.iloc[:, 1].values) # Dependent Variable

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
accuracy = regressor.score(X_test, y_test)
print('Accuracy = '+ str(accuracy))
# Out:
# Accuracy = 0.9872205033959207

# %%
X_grid = np.arange(min(X_test), max(X_test), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X_test, y_test, c = 'red', marker = 'o', s = 35, alpha = 0.5,
          label = 'Test data')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue', label='Model Plot')
plt.title('Predicted Values vs Inputs')
plt.xlabel('Position level')
plt.ylabel('Predicted Values')
plt.legend(loc = 'upper left')
plt.show()
